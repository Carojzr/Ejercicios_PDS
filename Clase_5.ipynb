# %% [markdown]
# ## Ejercicio clase 5
#
# ### Convolución

# %% [markdown]
# ### Librerias

# %%
import numpy as np 
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
sec = np.random.randint(0,20,15)
print('Secuencia 1: ',sec)

h = np.random.randint(0,20,15)
print('Secuencia 2: ',h)

convol = np.convolve(sec,h,mode='full')
tiempo = np.arange(0,29) 

plt.figure(figsize=(15,5))
plt.title('Convolución')
plt.xlabel('Muestras')
plt.ylabel('Amplitud')
plt.stem(tiempo,convol)
plt.grid()
plt.show()
# Out:
# Secuencia 1:  [14  4  0 13 11 14  5  1  9  2  3 12 14 15  8]
# Secuencia 2:  [10  2 12  9 11  8  7  8  7 19  6 16  1 12 11]

# %% [markdown]
# **La muestra cero esta en la posición cero en ambas secuencias**
