# %% [markdown]
# ## Ejercicio clase 3
#
# ### Representación por secuencia

# %% [markdown]
# ## Librerias

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
secuencia = np.random.randint(0,20,15)
print(secuencia)
# Out:
# [ 6 14  2 18  5  6 15 15 15 19  4  7 12 11 17]

# %%
tiempo = np.arange(len(secuencia)) 
plt.figure(figsize=(15,5))
plt.title('Secuencia')
plt.xlabel('Muestras')
plt.ylabel('Amplitud')
plt.stem(tiempo,secuencia,)
plt.grid()
